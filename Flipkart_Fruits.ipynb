# %%
# !unzip /content/fruits-fresh-rotten-classification-master.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.42.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.43.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.44.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.45.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.45.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.45.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.46.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.46.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.46.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.46.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.46.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.47.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.47.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.47.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.47.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.48.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.49.27 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.49.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.50.14 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.50.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.50.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.50.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.50.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.51.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.51.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.51.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.52.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.52.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_60_Screen Shot 2018-06-08 at 2.53.14 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.15.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.15.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.16.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.16.41 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.16.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.17.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.17.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.18.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.18.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.19.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.19.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.20.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.20.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.20.34 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.20.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.20.56 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.22.39 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.23.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.23.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.23.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.24.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.24.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.24.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.24.59 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.25.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.31.59 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.33.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.33.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.34.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.34.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.35.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.35.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.35.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.36.06 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.37.01 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.37.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.37.32 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.37.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.37.53 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.38.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.38.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.38.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.38.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.38.59 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.39.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.39.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.40.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.40.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.40.48 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.40.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.41.07 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.41.14 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.42.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.42.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.42.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.07 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.34 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.48 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.44.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.44.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.44.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.45.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.45.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.45.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.45.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.46.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.46.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.46.32 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.46.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.46.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.47.01 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.47.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.47.27 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.47.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.47.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.50.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.50.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.50.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.51.01 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.51.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.51.16 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.51.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.51.45 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.52.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.52.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.52.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.52.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.53.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.53.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.54.41 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.54.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.55.27 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.55.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.56.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.56.16 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.56.34 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.56.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.56.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.57.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.57.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.57.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.57.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.57.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.58.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.59.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.59.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.59.23 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.59.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.59.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.00.56 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.01.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.01.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.01.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.01.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.02.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.02.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.02.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.02.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.12 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.31 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.03.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.24 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.41 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.04.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.05 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.53 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.05.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.06.06 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.06.11 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.06.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.17.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 3.17.32 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.21.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.23.48 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.24.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.24.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.24.31 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.24.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.24.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.25.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.25.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.25.24 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.26.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.26.34 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.26.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.26.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.27.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.27.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.28.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.28.07 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.28.12 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.28.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.29.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.29.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.29.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.31 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.45 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.30.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.31.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.31.23 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.31.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.32.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.32.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.33.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.33.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.34.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.34.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.34.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.35.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.35.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.35.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.35.32 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.35.37 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.36.01 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.36.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.36.23 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.36.31 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.36.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.37.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.37.19 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.37.24 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.37.53 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.38.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.38.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.39.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.39.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.39.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.39.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.39.51 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.40.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.40.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.40.56 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.41.16 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.41.39 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.41.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.42.06 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.42.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.42.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.42.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.44.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.45.05 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.45.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.45.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.45.58 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.46.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.46.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.46.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.46.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.47.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.47.30 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.48.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.48.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.48.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.48.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.48.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.49.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.14 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.50.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.51.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.51.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.51.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.51.55 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.52.05 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.52.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.52.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/rotated_by_75_Screen Shot 2018-06-08 at 2.53.14 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.15.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.15.50 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.16.41 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.17.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.17.25 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.18.13 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.19.15 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.19.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.20.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.20.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.20.34 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.20.46 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.20.56 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.21.09 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.22.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.22.39 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.23.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.23.40 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.24.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.24.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.24.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.24.59 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.25.16 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.25.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.31.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.31.59 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.33.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.34.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.34.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.34.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.35.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.35.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.35.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.36.06 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.36.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.01 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.11 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.32 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.43 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.37.53 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.38.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.38.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.38.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.39.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.39.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.39.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.39.53 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.40.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 2.40.28 PM.png
# ...
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.39.02 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.39.19 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.39.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.40.18 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.40.23 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.40.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.40.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.35 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.44 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.41.48 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.00 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.05 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.20 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.38 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.42.52 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.03 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.10 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.22 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.31 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.36 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.49 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.43.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.06 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.16 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.24 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.29 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.39 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.44.54 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.12 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.21 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.28 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.33 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.42 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.47 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.45.57 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.46.04 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.46.17 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.46.26 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.46.56 PM.png
#   inflating: fruits-fresh-rotten-classification-master/Datasets/train/rottenoranges/vertical_flip_Screen Shot 2018-06-12 at 11.47.08 PM.png
#   inflating: fruits-fresh-rotten-classification-master/README.md
#   inflating: fruits-fresh-rotten-classification-master/fresh-rotten-fruits-improve.ipynb
#   inflating: fruits-fresh-rotten-classification-master/fresh_rotten_fruit_baseline.ipynb
#    creating: fruits-fresh-rotten-classification-master/upload test/
#    creating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-apple.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-apple2.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-banana.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-banana2.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit14.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit18.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit19.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit21.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit22.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit23.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit24.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/fresh-fruit8.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-apple.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit2.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit21.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit22.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit23.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit24.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit4.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit6.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-fruit8.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-orange2.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Apple, Banana, Orange/rotten-orange3.jpeg
#    creating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/WhatsApp Image 2020-06-18 at 17.48.00.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-banana.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-banana2.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit11.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit14.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit17.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit17x.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit20.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit23.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit7.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/fresh-fruit9.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/rotten-fruit24.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/rotten-fruit4.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/Wrong predict/rotten-fruit6.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit10.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit11.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit12.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit13.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit14.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit15.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit16.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit17.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit18.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit19.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit2.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit20.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit21.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit22.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit22.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit23.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit24.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit25.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit26.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit3.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit4.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit5.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit6.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit7.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit8.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/fresh-fruit9.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit10.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit11.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit12.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit13.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit14.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit15.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit16.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit17.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit18.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit19.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit2.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit20.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit21.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit22.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit23.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit24.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit25.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit26.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit3.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit4.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit5.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit6.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit7.jpg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit8.jpeg
#   inflating: fruits-fresh-rotten-classification-master/upload test/rotten-fruit9.jpeg

# %%
import os
import zipfile
import random
import shutil
import numpy as np
from shutil import copyfile

# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

import tensorflow as tf
from google.colab import files
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.17.0

# %%
local_zip = '/tmp/data.zip'
zip_ref = zipfile.ZipFile('/content/fruits-fresh-rotten-classification-master.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def make_dir(PATH):
  if not os.path.exists(PATH):
      os.mkdir(PATH)
      return PATH
  else:
    shutil.rmtree(PATH)
    os.mkdir(PATH)
    return PATH

# %%
try:
    base_dir = '/tmp'
    fruit_dir = make_dir(os.path.join(base_dir, 'fruit-dataset'))
    train_dir = make_dir(os.path.join(fruit_dir, 'train'))
    validation_dir = make_dir(os.path.join(fruit_dir, 'val'))
    test_dir = make_dir(os.path.join(fruit_dir, 'test'))
    preview_dir = make_dir(os.path.join(fruit_dir, 'preview'))

    train_fresh_apples_dir = make_dir(os.path.join(train_dir, 'Fresh Apples'))
    train_fresh_bananas_dir = make_dir(os.path.join(train_dir, 'Fresh Bananas'))
    train_fresh_oranges_dir = make_dir(os.path.join(train_dir, 'Fresh Oranges'))
    train_rotten_apples_dir = make_dir(os.path.join(train_dir, 'Rotten Apples'))
    train_rotten_bananas_dir = make_dir(os.path.join(train_dir, 'Rotten Bananas'))
    train_rotten_oranges_dir = make_dir(os.path.join(train_dir, 'Rotten Oranges'))

    validation_fresh_apples_dir = make_dir(os.path.join(validation_dir, 'Fresh Apples'))
    validation_fresh_bananas_dir = make_dir(os.path.join(validation_dir, 'Fresh Bananas'))
    validation_fresh_oranges_dir = make_dir(os.path.join(validation_dir, 'Fresh Oranges'))
    validation_rotten_apples_dir = make_dir(os.path.join(validation_dir, 'Rotten Apples'))
    validation_rotten_bananas_dir = make_dir(os.path.join(validation_dir, 'Rotten Bananas'))
    validation_rotten_oranges_dir = make_dir(os.path.join(validation_dir, 'Rotten Oranges'))

    test_fresh_apples_dir = make_dir(os.path.join(test_dir, 'Fresh Apples'))
    test_fresh_bananas_dir = make_dir(os.path.join(test_dir, 'Fresh Bananas'))
    test_fresh_oranges_dir = make_dir(os.path.join(test_dir, 'Fresh Oranges'))
    test_rotten_apples_dir = make_dir(os.path.join(test_dir, 'Rotten Apples'))
    test_rotten_bananas_dir = make_dir(os.path.join(test_dir, 'Rotten Bananas'))
    test_rotten_oranges_dir = make_dir(os.path.join(test_dir, 'Rotten Oranges'))

except OSError:
    pass

# %%
from PIL import Image

def split_data(SOURCE='', TRAINING='', VALIDATION='', SPLIT_SIZE=0):
  data = os.listdir(SOURCE)
  random_data = random.sample(data, len(data))

  train_size = len(data)*SPLIT_SIZE

  for i, filename in enumerate(random_data):
    filepath = os.path.join(SOURCE, filename)
    if os.path.getsize(filepath) > 0:
      if i < train_size:
        copyfile(filepath, os.path.join(TRAINING, filename))
        # img = Image.open(os.path.join(TRAINING, filename)).convert('L')
        # img.save(os.path.join(TRAINING, filename))
      else:
        copyfile(filepath, os.path.join(VALIDATION, filename))
        # img = Image.open(os.path.join(VALIDATION, filename)).convert('L')
        # img.save(os.path.join(VALIDATION, filename))

# %%
dataset_train_dir = '/content/fruits-fresh-rotten-classification-master/Datasets/train'
dataset_test_dir = '/content/fruits-fresh-rotten-classification-master/Datasets/test'

fapples_train_dir = os.path.join(dataset_train_dir, 'freshapples')
fbananas_train_dir = os.path.join(dataset_train_dir, 'freshbanana')
foranges_train_dir = os.path.join(dataset_train_dir, 'freshoranges')
rapples_train_dir = os.path.join(dataset_train_dir, 'rottenapples')
rbananas_train_dir = os.path.join(dataset_train_dir, 'rottenbanana')
roranges_train_dir = os.path.join(dataset_train_dir, 'rottenoranges')

fapples_test_dir = os.path.join(dataset_test_dir, 'freshapples')
fbananas_test_dir = os.path.join(dataset_test_dir, 'freshbanana')
foranges_test_dir = os.path.join(dataset_test_dir, 'freshoranges')
rapples_test_dir = os.path.join(dataset_test_dir, 'rottenapples')
rbananas_test_dir = os.path.join(dataset_test_dir, 'rottenbanana')
roranges_test_dir = os.path.join(dataset_test_dir, 'rottenoranges')

print('fapples_train images = ', len(os.listdir(fapples_train_dir)))
print('fbananas_train images = ', len(os.listdir(fbananas_train_dir)))
print('foranges_train images = ', len(os.listdir(foranges_train_dir)))
print('rapples_train images = ', len(os.listdir(rapples_train_dir)))
print('rbananas_train images = ', len(os.listdir(rbananas_train_dir)))
print('roranges_train images = ', len(os.listdir(roranges_train_dir)))
print()
print('fapples_test images = ', len(os.listdir(fapples_test_dir)))
print('fbananas_test images = ', len(os.listdir(fbananas_test_dir)))
print('foranges_test images = ', len(os.listdir(foranges_test_dir)))
print('rapples_test images = ', len(os.listdir(rapples_test_dir)))
print('rbananas_test images = ', len(os.listdir(rbananas_test_dir)))
print('roranges_test images = ', len(os.listdir(roranges_test_dir)))
# Out:
# fapples_train images =  1693
# fbananas_train images =  1581
# foranges_train images =  1466
# rapples_train images =  2342
# rbananas_train images =  2224
# roranges_train images =  1595
#
# fapples_test images =  395
# fbananas_test images =  381
# foranges_test images =  388
# rapples_test images =  601
# rbananas_test images =  530
# roranges_test images =  403

# %%
SPLIT_SIZE = 0.67
split_data(fapples_train_dir, train_fresh_apples_dir, validation_fresh_apples_dir, SPLIT_SIZE)
split_data(fbananas_train_dir, train_fresh_bananas_dir, validation_fresh_bananas_dir, SPLIT_SIZE)
split_data(foranges_train_dir, train_fresh_oranges_dir, validation_fresh_oranges_dir, SPLIT_SIZE)
split_data(rapples_train_dir, train_rotten_apples_dir, validation_rotten_apples_dir, SPLIT_SIZE)
split_data(rbananas_train_dir, train_rotten_bananas_dir, validation_rotten_bananas_dir, SPLIT_SIZE)
split_data(roranges_train_dir, train_rotten_oranges_dir, validation_rotten_oranges_dir, SPLIT_SIZE)

SPLIT_SIZE = 1.0
split_data(fapples_test_dir, test_fresh_apples_dir, validation_fresh_apples_dir, SPLIT_SIZE)
split_data(fbananas_test_dir, test_fresh_bananas_dir, validation_fresh_bananas_dir, SPLIT_SIZE)
split_data(foranges_test_dir, test_fresh_oranges_dir, validation_fresh_oranges_dir, SPLIT_SIZE)
split_data(rapples_test_dir, test_rotten_apples_dir, validation_rotten_apples_dir, SPLIT_SIZE)
split_data(rbananas_test_dir, test_rotten_bananas_dir, validation_rotten_bananas_dir, SPLIT_SIZE)
split_data(roranges_test_dir, test_rotten_oranges_dir, validation_rotten_oranges_dir, SPLIT_SIZE)

# %%
print(len(os.listdir('/tmp/fruit-dataset/train/Fresh Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/train/Fresh Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/train/Fresh Oranges/')))
print(len(os.listdir('/tmp/fruit-dataset/train/Rotten Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/train/Rotten Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/train/Rotten Oranges/')))
print()
print(len(os.listdir('/tmp/fruit-dataset/val/Fresh Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/val/Fresh Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/val/Fresh Oranges/')))
print(len(os.listdir('/tmp/fruit-dataset/val/Rotten Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/val/Rotten Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/val/Rotten Oranges/')))
print()
print(len(os.listdir('/tmp/fruit-dataset/test/Fresh Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/test/Fresh Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/test/Fresh Oranges/')))
print(len(os.listdir('/tmp/fruit-dataset/test/Rotten Apples/')))
print(len(os.listdir('/tmp/fruit-dataset/test/Rotten Bananas/')))
print(len(os.listdir('/tmp/fruit-dataset/test/Rotten Oranges/')))
# Out:
# 1135
# 1060
# 983
# 1570
# 1491
# 1069
#
# 558
# 521
# 483
# 772
# 733
# 526
#
# 395
# 381
# 388
# 601
# 530
# 403

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.2, #0.2, 0.5
    height_shift_range=0.2, #0.2, 0.5
    shear_range=0.2,
    zoom_range=[0.5, 1.0], # 0.2, 0.5, [0.5,1.0]
    rotation_range=90, #20, 40, 60, 90
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect' #nearest, reflect, wrap
)

validation_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
path_aug = os.path.join(train_fresh_apples_dir, os.listdir(train_fresh_apples_dir)[-1])
img_augmentation = image.load_img(path_aug)
x_aug = image.img_to_array(img_augmentation)
x_aug = x_aug.reshape((1,) + x_aug.shape)

i = 0
for batch in train_datagen.flow(x_aug, batch_size=1, save_to_dir=preview_dir, save_prefix='fruit', save_format='jpeg'):
    i += 1
    if i >= 20:
        break

preview_img = os.listdir(preview_dir)

plt.figure(figsize=(15, 15))
for n in range(len(preview_img)):
  plt.subplot((len(preview_img)//4)+1, 4, n+1)
  plt.subplots_adjust(hspace = 0.3)
  plt.imshow(image.load_img(os.path.join(preview_dir, preview_img[n]),
                            color_mode="rgb",
                            target_size=(150, 150),
                            interpolation="nearest"))
  plt.axis('off')
plt.show()

for fn in preview_img:
  os.system(f'rm {os.path.join(preview_dir, fn)}')

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    color_mode="rgb",
                                                    # shuffle = False,
                                                    target_size=(150,150), #?
                                                    class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(validation_dir,
                                                         batch_size=32,
                                                         color_mode="rgb",
                                                         # shuffle = False,
                                                         target_size=(150,150), #?
                                                         class_mode='categorical')
# Out:
# Found 7308 images belonging to 6 classes.
# Found 3593 images belonging to 6 classes.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.98):
      print("\nReached 98% accuracy. Stop Training")
      self.model.stop_training = True

callbacks = myCallback()

# %%
#if you want to use tranfer learning, skip this cell
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(6, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36992)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      18,940,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │           3,078 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,036,742 (72.62 MB)
#  Trainable params: 19,036,742 (72.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers
from tensorflow.keras import Model
import pandas as pd

pre_trained_model = InceptionV3(input_shape=(150,150,3),
                                include_top=False)

for layer in pre_trained_model.layers:
    layer.trainable = False

x = layers.Flatten()(pre_trained_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(6, activation='softmax')(x)

model = Model(pre_trained_model.input, x)
model.compile(optimizer='adam', #RMSprop(lr=0.0001), adam
              loss='categorical_crossentropy',
              metrics=['accuracy'])

pd.set_option('max_colwidth', None)
layers = [(layer, layer.name, layer.trainable) for layer in pre_trained_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#                                                     Layer Type  \
# 0                  <InputLayer name=input_layer_1, built=True>
# 1                           <Conv2D name=conv2d_3, built=True>
# 2    <BatchNormalization name=batch_normalization, built=True>
# 3                     <Activation name=activation, built=True>
# 4                           <Conv2D name=conv2d_4, built=True>
# ..                                                         ...
# 306                <Activation name=activation_85, built=True>
# 307                    <Concatenate name=mixed9_1, built=True>
# 308               <Concatenate name=concatenate_1, built=True>
# 309                <Activation name=activation_93, built=True>
# 310                     <Concatenate name=mixed10, built=True>
#
#               Layer Name  Layer Trainable
# 0          input_layer_1            False
# 1               conv2d_3            False
# 2    batch_normalization            False
# 3             activation            False
# 4               conv2d_4            False
# ..                   ...              ...
# 306        activation_85            False
# 307             mixed9_1            False
# 308        concatenate_1            False
# 309        activation_93            False
# 310              mixed10            False
#
# [311 rows x 3 columns]

# %%
train_len = 0
for foldername in os.listdir('/tmp/fruit-dataset/train'):
    train_len = train_len + len(os.listdir(os.path.join('/tmp/fruit-dataset/train',foldername)))

val_len = 0
for foldername in os.listdir('/tmp/fruit-dataset/val'):
    val_len = val_len + len(os.listdir(os.path.join('/tmp/fruit-dataset/val',foldername)))

print(train_len)
print(val_len)
# Out:
# 7308
# 3593

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=(train_len//32),
    epochs=3,
    verbose=1,
    callbacks=[callbacks],
    validation_data=validation_generator,
    validation_steps=(val_len//32)
)
# Out:
# Epoch 1/3
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 740s 3s/step - accuracy: 0.7325 - loss: 11.0915 - val_accuracy: 0.9149 - val_loss: 0.2509
# Epoch 2/3
#   1/228 ━━━━━━━━━━━━━━━━━━━━ 6:39 2s/step - accuracy: 0.9688 - loss: 0.1348
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9688 - loss: 0.1348 - val_accuracy: 1.0000 - val_loss: 0.1071
# Epoch 3/3
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 724s 3s/step - accuracy: 0.9016 - loss: 0.2981 - val_accuracy: 0.9219 - val_loss: 0.2421

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.figure()

plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('Training and Validaion Loss')
plt.figure()

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  batch_size=1,
                                                  target_size=(150, 150),
                                                  shuffle = False,
                                                  class_mode='categorical')

filenames = test_generator.filenames
nb_samples = len(filenames)

loss, acc = model.evaluate(test_generator,steps = (nb_samples), verbose=1)
print('accuracy test: ',acc)
# Out:
# Found 2698 images belonging to 6 classes.
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 237s 88ms/step - accuracy: 0.9663 - loss: 0.1300
# accuracy test:  0.9362490773200989

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.utils import load_img, img_to_array
import pathlib
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os


model_predict = tf.keras.models.load_model('model.h5')
model_predict.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

# uploaded is a string, not a dictionary, so it doesn't have keys()
uploaded = '/content/download (10).jpeg'
image_name = []
image_conf = []
predict_result = []

# Process the single image directly instead of iterating
path = uploaded
img = load_img(path, color_mode="rgb", target_size=(150, 150), interpolation="nearest")
# imgplot = plt.imshow(img)
img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255

images = np.vstack([img])
classes = model_predict.predict(images, batch_size=10)

max = np.amax(classes[0])
if np.where(classes[0] == max)[0] == 0:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Fresh')
elif np.where(classes[0] == max)[0] == 1:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Fresh')
elif np.where(classes[0] == max)[0] == 2:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Fresh')
elif np.where(classes[0] == max)[0] == 3:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Rotten')
elif np.where(classes[0] == max)[0] == 4:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Rotten')
else:
    image_name.append(path)  # Append the path
    image_conf.append(max)
    predict_result.append('Rotten')

plt.figure(figsize=(15, 15))
for n in range(len(image_name)):
    plt.subplot((len(image_name)//4)+1, 4, n+1)
    plt.subplots_adjust(hspace = 0.3)
    plt.imshow(load_img(image_name[n], color_mode="rgb", target_size=(150, 150), interpolation="nearest"))
    title = f"predict: {predict_result[n]} ({round(float(image_conf[n])*100, 2)}%)"
    plt.title(title, color='black')
    plt.axis('off')
plt.show()

for fn in image_name:
  os.system(f'rm {fn}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
